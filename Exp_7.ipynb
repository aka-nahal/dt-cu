# %% [markdown]
# <a href="https://colab.research.google.com/github/aka-nahal/dt-i-cu/blob/main/Exp_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Experiment 7
# Aim:- Desgin am AI enabed application for emotion gesture detection.
# Dated on 28th Novemeber

# %% [markdown]
# **Input Signal** --> **Signal Processing Module** --> **Classification** --> **Emotion Recongnition**

# %%
# Deepface is a Lightweight Face Recognition and Facial Attribute Analysis Framework (Age, Gender, Emotion, Race) for Python
# !pip install deepface &> /dev/null # &> /dev/null for hiding the installation log
print("Deep Face Installed Successfully")
# Out:
# Deep Face Installed Successfully

# %%
from deepface import DeepFace
import cv2 # used to read the images
import matplotlib.pyplot as plt
img1=cv2.imread("/content/avatars-000112058053-3jw7k9-t500x500.jpg")
plt.imshow(img1)
plt.show()

# BGR format :-
# bThe BGR is a 24-bit representation where the lower-addressed 8 bits are blue, the next-addressed 8 are green and higher-addressed 8 are red. RGB values tend to be written as RGB(r,g,b) where the r/g/b values are between 0 and 255 inclusive or as #rrggbb, where rr/gg/bb are 8-bit hex values.

# %%
# plotting the image
# flipping the color from BGR to RGB
plt.imshow(img1[:, :, ::-1 ])
plt.show()

# %%
## Analyze Image
obj=DeepFace.analyze(img1,actions = ['age','gender','race','emotion']) # analazing user-fined parameters
print(obj)
# Out:
# ...
# Action: emotion: 100%|██████████| 4/4 [00:01<00:00,  2.36it/s]
# {'age': 29, 'region': {'x': 158, 'y': 104, 'w': 215, 'h': 215}, 'gender': 'Man', 'race': {'asian': 7.4013851583004, 'indian': 25.172945857048035, 'black': 19.38014328479767, 'white': 9.131959825754166, 'middle eastern': 14.072221517562866, 'latino hispanic': 24.841344356536865}, 'dominant_race': 'indian', 'emotion': {'angry': 1.846783574308923, 'disgust': 0.0005001853282371564, 'fear': 0.015991444073706083, 'happy': 0.12484442817039154, 'sad': 74.50811570786051, 'surprise': 2.185510400801291e-08, 'neutral': 23.50376117184625}, 'dominant_emotion': 'sad'}

# %%
# print result
print("Your age is",obj["age"],"and you belong to",obj["gender"],"species you are",obj["dominant_race"], "and current emotion is",obj["dominant_emotion"])
# Out:
# Your age is 29 and you belong to Man species you are indian and current emotion is sad
